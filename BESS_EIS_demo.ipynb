# %%
# !pip install numpy pandas matplotlib scipy openpyxl galvani

# %%
# %run eis_battery_diagnostics.py
# Out:
# {
#     "circuit": "dual_arc_battery",
#     "r0_intercept_ohm": 0.001115,
#     "intercept_frequency_hz": 2782.56,
#     "r0_based_health_indicator_percent": 51.27,
#     "asset_status": "HEALTHY",
#     "alerts": [
#         "No critical alerts."
#     ],
#     "fitted_parameters": {
#         "Rs": 0.000717,
#         "L": 0.0,
#         "Rsei": 0.004298,
#         "Qsei": 7.264525,
#         "alpha_sei": 1.0,
#         "Rct": 0.120047,
#         "Qdl": 9.146825,
#         "alpha_dl": 0.589645,
#         "sigma_w": 0.0
#     },
#     "parameter_uncertainty_1sigma": {
#         "Rs": 0.0001,
#         "L": 0.0001,
#         "Rsei": 0.0001,
#         "Qsei": 0.0001,
#         "alpha_sei": 0.0001,
#         "Rct": 0.0001,
#         "Qdl": 0.0001,
#         "alpha_dl": 0.0001,
#         "sigma_w": 0.0001
#     },
#     "fit_metrics": {
#         "rmse_real_ohm": 0.0001,
#         "rmse_imag_ohm": 0.0001,
#         "rmse_abs_ohm": 0.0001,
#         "nrmse_percent": 0.2,
# ...
